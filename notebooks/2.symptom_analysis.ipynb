# %% [markdown]
# # Symptom Analysis
#
# This notebook provides comprehensive analysis of symptom data including:
# 1. **Symptom Mapping Quality** - How well Mayo Clinic symptoms map to vocabulary
# 2. **Duplicate Detection** - Find redundant symptoms across datasets
# 3. **Merge Impact Analysis** - What happens when we consolidate duplicates
#
# ---

# %%
import pandas as pd
import json
import sys
from pathlib import Path
from difflib import SequenceMatcher
import re

# Set project root
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))

from utils.symptom_normalizer import normalize_symptom, TYPO_MAP, SYNONYM_MAP, PLURAL_MAP

print(f"Project root: {project_root}")
# Out:
# Project root: c:\Users\henry\Desktop\Programming\Python\Multimodal_Diagnosis

# %% [markdown]
# ## 1. Symptom Mapping Quality Analysis
#
# Analyzes how well the `mayo_clinic_symptoms` in the template map to the standardized vocabulary.

# %%
# Load vocabulary and template
symptom_vocab_path = project_root / "data" / "symptom_vocabulary.json"
template_path = project_root / "data" / "rare_diseases_symptoms_template.json"

with open(symptom_vocab_path) as f:
    VOCABULARY = json.load(f)
VOCAB_SET = set(s.lower() for s in VOCABULARY)
VOCAB_LOOKUP = {s.lower(): s for s in VOCABULARY}

with open(template_path) as f:
    template = json.load(f)

print(f"Vocabulary size: {len(VOCABULARY)} symptoms")
print(f"Template diseases: {len(template)} diseases")
# Out:
# Vocabulary size: 454 symptoms
# Template diseases: 135 diseases

# %%
def tokenize(text: str) -> set:
    """Convert text to lowercase tokens."""
    text = text.lower()
    text = re.sub(r'[^\w\s]', ' ', text)
    return set(text.split())

def similarity_score(a: str, b: str) -> float:
    """Calculate similarity between two strings."""
    tokens_a = tokenize(a)
    tokens_b = tokenize(b)
    
    if not tokens_a or not tokens_b:
        return 0.0
    
    overlap = len(tokens_a & tokens_b)
    total = len(tokens_a | tokens_b)
    jaccard = overlap / total if total > 0 else 0
    seq_ratio = SequenceMatcher(None, a.lower(), b.lower()).ratio()
    
    return 0.6 * jaccard + 0.4 * seq_ratio

def find_best_match(symptom: str, top_n: int = 3) -> list:
    """Find best matching symptoms from vocabulary."""
    symptom_lower = symptom.lower().strip()
    
    # Exact match
    if symptom_lower in VOCAB_SET:
        return [(VOCAB_LOOKUP[symptom_lower], 1.0)]
    
    # Fuzzy match
    scores = [(vocab_symptom, similarity_score(symptom, vocab_symptom)) 
              for vocab_symptom in VOCABULARY]
    scores.sort(key=lambda x: -x[1])
    return scores[:top_n]

# %%
# Collect all mayo_clinic_symptoms
all_mayo_symptoms = set()
for disease, info in template.items():
    mayo = info.get("mayo_clinic_symptoms", [])
    all_mayo_symptoms.update(mayo)

print(f"Total unique mayo_clinic_symptoms: {len(all_mayo_symptoms)}")

# Categorize by match quality
exact_matches = []
good_matches = []  # > 0.7 similarity
poor_matches = []  # 0.4 - 0.7
no_matches = []    # < 0.4

for symptom in sorted(all_mayo_symptoms):
    matches = find_best_match(symptom)
    best_match, best_score = matches[0]
    
    if best_score == 1.0:
        exact_matches.append(symptom)
    elif best_score >= 0.7:
        good_matches.append((symptom, best_match, best_score))
    elif best_score >= 0.4:
        poor_matches.append((symptom, best_match, best_score))
    else:
        no_matches.append((symptom, best_match, best_score))

print(f"\n--- MATCH QUALITY SUMMARY ---")
print(f"EXACT MATCHES (100%):     {len(exact_matches):4d} ({100*len(exact_matches)/len(all_mayo_symptoms):.1f}%)")
print(f"GOOD MATCHES (70-99%):    {len(good_matches):4d} ({100*len(good_matches)/len(all_mayo_symptoms):.1f}%)")
print(f"POOR MATCHES (40-69%):    {len(poor_matches):4d} ({100*len(poor_matches)/len(all_mayo_symptoms):.1f}%)")
print(f"NO MATCH (<40%):          {len(no_matches):4d} ({100*len(no_matches)/len(all_mayo_symptoms):.1f}%)")
print(f"\nUSABLE (exact + good):    {len(exact_matches) + len(good_matches):4d} ({100*(len(exact_matches) + len(good_matches))/len(all_mayo_symptoms):.1f}%)")
# Out:
# Total unique mayo_clinic_symptoms: 767
#
# --- MATCH QUALITY SUMMARY ---
# EXACT MATCHES (100%):      141 (18.4%)
# GOOD MATCHES (70-99%):      12 (1.6%)
# POOR MATCHES (40-69%):     306 (39.9%)
# NO MATCH (<40%):           308 (40.2%)
#
# USABLE (exact + good):     153 (19.9%)

# %%
# Show poor matches that need attention
print("--- POOR MATCHES (Need Manual Mapping) ---")
for s, m, score in sorted(poor_matches, key=lambda x: -x[2]):
    print(f"  [{int(score*100):3d}%] \"{s}\" -> \"{m}\"")

print(f"\n--- NO MATCH (Need to Add to Vocabulary) ---")
for s, m, score in sorted(no_matches, key=lambda x: -x[2]):
    print(f"  [{int(score*100):3d}%] \"{s}\" (closest: \"{m}\")")
# Out:
# --- POOR MATCHES (Need Manual Mapping) ---
#   [ 69%] "loss of consiousness" -> "loss of consciousness"
#   [ 68%] "nausea and vomitting" -> "nausea and vomiting"
#   [ 68%] "loss of apetite" -> "loss of appetite"
#   [ 68%] "ringing in ears" -> "ringing in ear"
#   [ 68%] "progressive muscle weakness" -> "muscle weakness"
#   [ 68%] "swelling of ankles and legs" -> "swelling of ankles"
#   [ 67%] "sudden swelling of the scrotum" -> "swelling of scrotum"
#   [ 66%] "no menstrual periods" -> "long menstrual periods"
#   [ 65%] "unexplained weight gain" -> "weight gain"
#   [ 65%] "unexplained weight loss" -> "weight loss"
#   [ 65%] "swelling in ankles" -> "swelling of ankles"
#   [ 65%] "changes in skin color" -> "skin color changes"
#   [ 65%] "swelling of legs" -> "swelling of ankles"
#   [ 64%] "swollen lymph glands" -> "swollen lymph nodes"
#   [ 64%] "fast heart beat" -> "fast heart rate"
#   [ 64%] "unintentional weight loss" -> "weight loss"
#   [ 64%] "swelling of hands" -> "swelling of ankles"
#   [ 64%] "lack of coordination" -> "loss of coordination"
#   [ 63%] "light sensitivity" -> "sensitivity to light"
#   [ 62%] "swelling of face" -> "swelling of ankles"
#   [ 62%] "toe stiffness" -> "stiffness"
#   [ 62%] "swollen tonsils" -> "swollen or red tonsils"
#   [ 62%] "redness of eye" -> "eye redness"
#   [ 62%] "heavy menstrual periods" -> "long menstrual periods"
#   [ 62%] "swelling of feets" -> "swelling of ankles"
#   [ 61%] "itching of the skin of the vulva" -> "itching of skin"
#   [ 61%] "foot weakness" -> "foot or toe weakness"
#   [ 61%] "neck stiffness" -> "stiffness"
#   [ 61%] "joint pain or swelling" -> "joint swelling"
#   [ 60%] "heavy menstrual bleeding" -> "heavy menstrual flow"
#   [ 60%] "lump on vulva" -> "mass on vulva"
#   [ 60%] "pain on vulva" -> "mass on vulva"
#   [ 60%] "sore on vulva" -> "mass on vulva"
#   [ 60%] "swelling of feet" -> "swelling of ankles"
#   [ 60%] "involuntary eye movements" -> "abnormal involuntary movements"
#   [ 60%] "hand weakness" -> "weakness"
#   [ 60%] "skin flushing" -> "flushing"
#   [ 60%] "swelling of eyelids" -> "swelling of ankles"
#   [ 60%] "night blindness" -> "blindness"
#   [ 60%] "teeth growth slow" -> "slow growth"
#   [ 59%] "severe infections" -> "infections"
#   [ 59%] "pain during sex" -> "pain during intercourse"
#   [ 59%] "swelling of thyroid" -> "swelling of scrotum"
#   [ 59%] "swelling of eyelid" -> "eyelid swelling"
#   [ 59%] "muscle pain in legs" -> "muscle pain"
#   [ 59%] "thigh weakness" -> "weakness"
#   [ 58%] "irregular heartbeats" -> "irregular heartbeat"
#   [ 58%] "irritable" -> "irritable infant"
#   [ 58%] "sleep problems in infants" -> "sleep problems"
#   [ 58%] "blood in feces" -> "blood in stool"
#   [ 58%] "ketones in urine" -> "pus in urine"
#   [ 58%] "protein in urine" -> "pus in urine"
#   [ 58%] "muscle tightness" -> "muscle stiffness or tightness"
#   [ 58%] "muscle or joint pain" -> "muscle pain"
#   [ 58%] "muscle aches" -> "muscle ache"
#   [ 57%] "blood pressure changes" -> "low blood pressure"
#   [ 57%] "facial swelling" -> "swelling"
#   [ 57%] "severe headache" -> "headache"
#   [ 57%] "tongue swelling" -> "swelling"
#   [ 57%] "blisters on skin" -> "wrinkles on skin"
#   [ 57%] "yellowing of skin" -> "itching of skin"
#   [ 57%] "coughing up blood" -> "coughing up sputum"
#   [ 57%] "pain in joint" -> "joint pain"
#   [ 56%] "dry mouth and lips" -> "dry mouth"
#   [ 56%] "gas pain" -> "pain"
#   [ 56%] "increased sleepiness" -> "sleepiness"
#   [ 56%] "lack of focus" -> "lack of growth"
#   [ 56%] "loss of smell" -> "loss of sensation"
#   [ 56%] "loss of touch" -> "loss of sensation"
#   [ 55%] "loss of balance" -> "loss of appetite"
#   [ 55%] "swelling of the legs" -> "swelling of ankles"
#   [ 55%] "blurry vision" -> "blurred vision"
#   [ 55%] "pain in the side" -> "pain in testicles"
#   [ 55%] "extreme fatigue" -> "fatigue"
#   [ 55%] "itching" -> "vaginal itching"
#   [ 55%] "discomfort in chest" -> "congestion in chest"
#   [ 55%] "eyelid redness" -> "eye redness"
#   [ 55%] "menstrual bleeding" -> "intermenstrual bleeding"
#   [ 55%] "loss of mobility" -> "loss of appetite"
#   [ 55%] "loss of reflexes" -> "loss of appetite"
#   [ 54%] "difficulty walking" -> "difficulty swallowing"
#   [ 54%] "lack of apetite" -> "lack of growth"
#   [ 54%] "abdominal bloating" -> "bloating"
#   [ 54%] "excessive sweating" -> "sweating"
#   [ 54%] "red or swollen throat" -> "swollen or red tonsils"
#   [ 54%] "frequent leg or foot infections" -> "frequent infections"
#   [ 54%] "difficulty feeding" -> "difficulty eating"
#   [ 54%] "pale skin color" -> "skin color changes"
#   [ 54%] "extreme thirst" -> "thirst"
#   [ 54%] "serious thirst" -> "thirst"
#   [ 53%] "swollen toes" -> "swollen tongue"
#   [ 53%] "lump in belly" -> "lump in throat"
#   [ 53%] "projectile vomiting" -> "vomiting"
#   [ 53%] "difficulty sleeping" -> "difficulty speaking"
#   [ 53%] "eyelid pain" -> "eye pain"
#   [ 53%] "nerve pain" -> "knee pain"
#   [ 53%] "difficulty thinking" -> "difficulty eating"
#   [ 53%] "swollen belly" -> "swollen eye"
#   [ 53%] "lack of attention" -> "lack of growth"
#   [ 53%] "lack of awareness" -> "lack of growth"
#   [ 52%] "hearing problems" -> "breathing problems"
#   [ 52%] "lack of muscle coordination" -> "loss of coordination"
#   [ 52%] "belly pain" -> "pain"
#   [ 52%] "chest pain when breathing" -> "chest pain"
#   [ 52%] "heaviness in the scrotum" -> "mass in scrotum"
#   [ 52%] "loss of brain function" -> "loss of coordination"
#   [ 52%] "pain in your neck" -> "pain in eye"
#   [ 52%] "abnormal spots on skin" -> "abnormal appearing skin"
#   [ 52%] "presistent fatigue" -> "fatigue"
#   [ 52%] "abnormal eye movement" -> "abnormal movement of eyelid"
#   [ 52%] "brittle hair" -> "brittle nails"
#   [ 52%] "memory problems" -> "temper problems"
#   [ 52%] "reduced urination" -> "frequent urination"
#   [ 51%] "excessive thirst" -> "thirst"
#   [ 51%] "lack of flexibility" -> "lack of growth"
#   [ 51%] "often urination" -> "frequent urination"
#   [ 51%] "hearing loss in one ear" -> "hearing loss"
#   [ 51%] "breast pain" -> "pain"
#   [ 51%] "leg pain while walking" -> "leg pain"
#   [ 51%] "swelling of the stomach" -> "swelling of ankles"
#   [ 51%] "swollen legs" -> "swollen eye"
#   [ 51%] "changes in speech" -> "changes in stool appearance"
#   [ 51%] "changes in alertness" -> "changes in stool appearance"
#   [ 51%] "strong or frequent uterine contractions" -> "uterine contractions"
#   [ 51%] "nail loss" -> "hair loss"
#   [ 50%] "kidney problems" -> "smoking problems"
#   [ 50%] "painful blisters" -> "painful sinuses"
#   [ 50%] "feeling bloated" -> "feeling hot"
#   [ 50%] "involuntary kerkin" -> "involuntary urination"
#   [ 50%] "bumps on lower legs" -> "bumps on penis"
#   [ 50%] "memory fog" -> "memory loss"
#   [ 50%] "heart problems" -> "temper problems"
#   [ 50%] "swollen fingers" -> "swollen tongue"
#   [ 50%] "increased sensitivity to cold" -> "sensitivity to light"
#   [ 50%] "swelling of affected tissues" -> "swelling of ankles"
#   [ 50%] "changes in voice" -> "changes in stool appearance"
#   [ 50%] "cold" -> "feeling cold"
#   [ 50%] "feeling tired" -> "feeling hot"
#   [ 50%] "involuntary jerking" -> "involuntary urination"
#   [ 50%] "kidney stones" -> "kidney mass"
#   [ 50%] "muscle spasms" -> "muscle pain"
#   [ 50%] "muscle tenderness" -> "muscle weakness"
#   [ 50%] "skin changes in color on vulva" -> "skin color changes"
#   [ 50%] "stomach pain" -> "pain"
#   [ 50%] "urinary retention" -> "fluid retention"
#   [ 49%] "hearing loss in both ears" -> "hearing loss"
#   [ 49%] "lump in either testicle" -> "lump in throat"
#   [ 49%] "pain in stomach area" -> "pain in testicles"
#   [ 49%] "pain in the groin" -> "pain in testicles"
#   [ 49%] "weight gain in the face" -> "weight gain"
#   [ 49%] "swelling of hands or eyes" -> "swelling of ankles"
#   [ 49%] "changes in color of breast skin" -> "skin color changes"
#   [ 49%] "joint ache" -> "bone ache"
#   [ 49%] "bleeding in genital area" -> "bleeding in mouth"
#   [ 49%] "abdominal cramps" -> "abdominal pain"
#   [ 49%] "blisters in the mouth" -> "bleeding in mouth"
#   [ 49%] "pus-like draining" -> "pus draining from ear"
#   [ 49%] "red streaks on skin" -> "wrinkles on skin"
#   [ 49%] "weight gain in the trunk" -> "weight gain"
#   [ 49%] "cloudy urine" -> "cloudy eye"
#   [ 49%] "poor coordination" -> "poor circulation"
#   [ 49%] "skin discoloration" -> "skin irritation"
#   [ 49%] "red bump on skin" -> "wrinkles on skin"
#   [ 48%] "coordination problems" -> "vision problems"
#   [ 48%] "lump on breast" -> "lump or mass of breast"
#   [ 48%] "vomiting large amounts of blood" -> "vomiting blood"
#   [ 48%] "bloody stool" -> "blood in stool"
#   [ 48%] "kidney disease" -> "kidney mass"
#   [ 48%] "slow speech" -> "slurred speech"
#   [ 48%] "stiff muscles" -> "sore muscles"
#   [ 48%] "feeling irritable" -> "feeling ill"
#   [ 48%] "reduced vision" -> "blurred vision"
#   [ 48%] "yellowing of the skin" -> "itching of skin"
#   [ 48%] "eyelid twitching" -> "eyelid swelling"
#   [ 48%] "musculoskeletal pain" -> "muscle pain"
#   [ 48%] "urinary problems" -> "vision problems"
#   [ 48%] "gastrointestinal bleeding" -> "intermenstrual bleeding"
#   [ 48%] "abdominal distention" -> "abdominal pain"
#   [ 48%] "long-term constipation" -> "constipation"
#   [ 48%] "increased urination" -> "frequent urination"
#   [ 48%] "eye watering" -> "eye pain"
#   [ 47%] "enlargement of the breast tissue" -> "postpartum problems of the breast"
#   [ 47%] "bone fractures" -> "bone ache"
#   [ 47%] "feeling weak" -> "feeling hot"
#   [ 47%] "leaking urine" -> "dark urine"
#   [ 47%] "mood swings" -> "mood changes"
#   [ 47%] "numbness in arm" -> "numbness"
#   [ 47%] "white patches in throat" -> "lump in throat"
#   [ 47%] "mental changes" -> "mood changes"
#   [ 47%] "eye inflammation" -> "eye deviation"
#   [ 47%] "muscle contracture" -> "muscle ache"
#   [ 47%] "slow breathing" -> "rapid breathing"
#   [ 47%] "swollen glands" -> "swollen abdomen"
#   [ 47%] "shallow breathing" -> "rapid breathing"
#   [ 47%] "trouble breathing" -> "rapid breathing"
#   [ 47%] "bleeding from mouthh or ums" -> "bleeding from ear"
#   [ 47%] "patches of lighter skin" -> "itching of skin"
#   [ 47%] "swollen lymph nodes in your groin or armpit" -> "swollen lymph nodes"
#   [ 47%] "fast heartbeats" -> "fast heart rate"
#   [ 46%] "breathing difficulties" -> "breathing fast"
#   [ 46%] "diarrhea or constipation" -> "constipation"
#   [ 46%] "enlarged thyroid" -> "enlarged liver"
#   [ 46%] "foamy urine" -> "dark urine"
#   [ 46%] "frail skin" -> "dry skin"
#   [ 46%] "involuntary spasms" -> "involuntary urination"
#   [ 46%] "irregular periods" -> "irregular heartbeat"
#   [ 46%] "itchy skin" -> "dry skin"
#   [ 46%] "numbness in arms" -> "numbness"
#   [ 46%] "numbness in legs" -> "numbness"
#   [ 46%] "poor vision" -> "double vision"
#   [ 46%] "stomach cramps" -> "muscle cramps"
#   [ 46%] "swelling in feet" -> "swelling"
#   [ 46%] "swelling in legs" -> "swelling"
#   [ 46%] "swollen conjunctiva" -> "swollen tongue"
#   [ 46%] "unexplained bleeding" -> "easy bleeding"
#   [ 46%] "weakness of face" -> "weakness"
#   [ 46%] "pulsing in the chest" -> "congestion in chest"
#   [ 46%] "aching foot pain" -> "foot or toe pain"
#   [ 46%] "burning foot pain at rest" -> "burning chest pain"
#   [ 45%] "breathing abnormalities" -> "breathing fast"
#   [ 45%] "nervousness" -> "anxiety and nervousness"
#   [ 45%] "irritable bowel" -> "irritable infant"
#   [ 45%] "breast changes" -> "vision changes"
#   [ 45%] "serious fatigue or weakness" -> "hand or finger weakness"
#   [ 45%] "shape change of breast" -> "problems with shape or size of breast"
#   [ 45%] "changes in skin colr" -> "changes in stool appearance"
#   [ 45%] "sore areas" -> "sore muscles"
#   [ 45%] "change in size of breast" -> "change in skin mole size or color"
#   [ 45%] "yellow skin" -> "dry skin"
#   [ 45%] "thin skin" -> "itching of skin"
#   [ 45%] "trouble with vision" -> "double vision"
#   [ 44%] "bright red bleeding from vagina" -> "bleeding from ear"
#   [ 44%] "eye muscle paralysis" -> "paralysis"
#   [ 44%] "muscle rigidity" -> "muscle wasting"
#   [ 44%] "coughing" -> "coughing up sputum"
#   [ 44%] "trouble swallowing" -> "difficulty swallowing"
#   [ 44%] "failure to gain weight" -> "weight gain"
#   [ 44%] "milky nipple discharge" -> "penile discharge"
#   [ 44%] "pink eye" -> "pain in eye"
#   [ 44%] "pain behind the eyes" -> "pain of the anus"
#   [ 44%] "discolored skin" -> "dry skin"
#   [ 44%] "eyelid tenderness" -> "eyelid retracted"
#   [ 44%] "difficulty hearing whispers" -> "difficulty eating"
#   [ 44%] "increase in breast pain" -> "pain in testicles"
#   [ 43%] "frequent vomiting or spitting up" -> "infant spitting up"
#   [ 43%] "infections of the vagina" -> "pain of the anus"
#   [ 43%] "rectal prolapse" -> "rectal bleeding"
#   [ 43%] "yellowing of the eyes" -> "itching of the anus"
#   [ 43%] "swelling around joints" -> "mass or swelling around the anus"
#   [ 43%] "drooping eyelid" -> "itchy eyelid"
#   [ 43%] "swelling in stomach" -> "swelling"
#   [ 43%] "vision less clear" -> "vision loss"
#   [ 43%] "pale skin" -> "dry skin"
#   [ 43%] "repeated lung infections" -> "infections"
#   [ 43%] "speech difficulty" -> "difficulty eating"
#   [ 43%] "urinary tract infections" -> "infections"
#   [ 43%] "facial skin lessions" -> "skin lesion"
#   [ 43%] "fully swollen eyelid" -> "swollen eye"
#   [ 43%] "painful mouth sores" -> "painful sinuses"
#   [ 43%] "uterine tenderness" -> "uterine contractions"
#   [ 43%] "large amounts of pale urine" -> "retention of urine"
#   [ 42%] "pelvic discomfort" -> "pelvic pain"
#   [ 42%] "poor apetite" -> "poor circulation"
#   [ 42%] "reddened skin" -> "dry skin"
#   [ 42%] "repeated sinus infections" -> "infections"
#   [ 42%] "swelling on perineum" -> "swelling"
#   [ 42%] "trouble speaking" -> "difficulty speaking"
#   [ 42%] "severe muscle contractions" -> "uterine contractions"
#   [ 42%] "golden or brown ring around the eyes" -> "mass or swelling around the anus"
#   [ 42%] "dry brittle hair" -> "brittle nails"
#   [ 42%] "elongated ears" -> "pulling at ears"
#   [ 42%] "changes in skin texture" -> "changes in stool appearance"
#   [ 42%] "unwell feeling" -> "feeling hot"
#   [ 42%] "high bmi" -> "high fever"
#   [ 42%] "language difficulty" -> "difficulty eating"
#   [ 41%] "irregular pupil shape" -> "irregular appearing scalp"
#   [ 41%] "chest discomfort" -> "chest pain"
#   [ 41%] "eyelid bump" -> "eyelid swelling"
#   [ 41%] "irregular mentrusal periods" -> "long menstrual periods"
#   [ 41%] "extreme loss of body heat" -> "loss of coordination"
#   [ 41%] "tingling in toes" -> "ringing in ear"
#   [ 41%] "vomiting after feeding" -> "vomiting"
#   [ 41%] "low levels of sex hormones" -> "loss of sex drive"
#   [ 41%] "tingling in fingers" -> "ringing in ear"
#   [ 41%] "bumps" -> "bumps on penis"
#   [ 40%] "purple shiny bumps on wrists" -> "bumps on penis"
#   [ 40%] "ear differences" -> "ear pain"
#   [ 40%] "spasms" -> "cramps and spasms"
#   [ 40%] "feeling full quickly" -> "feeling ill"
#   [ 40%] "joint deformities" -> "joint pain"
#   [ 40%] "heart failure" -> "heart palpitations"
#   [ 40%] "problems sleeping" -> "sleep problems"
#   [ 40%] "black stool" -> "blood in stool"
#   [ 40%] "increased eye floaters" -> "increased heart rate"
#   [ 40%] "bumps under skin or a rash" -> "skin rash"
#   [ 40%] "painful sores in the mouth" -> "bleeding in mouth"
#   [ 40%] "lines of rash" -> "skin rash"
#   [ 40%] "runny nose" -> "sore in nose"
#   [ 40%] "lost of vision" -> "loss of sensation"
#   [ 40%] "burning during urination" -> "painful urination"
#   [ 40%] "bone tenderness" -> "bone ache"
#   [ 40%] "long-term cough" -> "cough"
#   [ 40%] "losing weight" -> "weight gain"
#   [ 40%] "pain in the area betweem vagina and anus" -> "pain of the anus"
#   [ 40%] "purple shiny bumps on forearms" -> "bumps on penis"
#   [ 40%] "visible stomach contractions" -> "uterine contractions"
#
# --- NO MATCH (Need to Add to Vocabulary) ---
#   [ 39%] "narrow toe nails" (closest: "brittle nails")
#   [ 39%] "cold sensitivity" (closest: "sensitivity to light")
#   [ 39%] "heat sensitivity" (closest: "sensitivity to light")
#   [ 39%] "yellowing of eyes" (closest: "swelling of ankles")
#   [ 39%] "heart disorders" (closest: "heart palpitations")
#   [ 39%] "urine that has unusual odor" (closest: "unusual color or odor to urine")
#   [ 39%] "abnormal bone growth" (closest: "abnormal heart rhythm")
#   [ 39%] "decreased muscle tone" (closest: "decreased heart rate")
#   [ 39%] "heavy bleeding during labour" (closest: "spotting or bleeding during pregnancy")
#   [ 39%] "small soft bumps under or around the nails" (closest: "mass or swelling around the anus")
#   [ 39%] "cough with blood" (closest: "cough")
#   [ 39%] "cough with mucus" (closest: "cough")
#   [ 38%] "slowed movement" (closest: "problems with movement")
#   [ 38%] "light-headedness" (closest: "lightheadedness")
#   [ 38%] "dry raspy throat" (closest: "sore throat")
#   [ 38%] "foul-smelling sputum" (closest: "pus in sputum")
#   [ 38%] "bronze or gray skin color" (closest: "skin color changes")
#   [ 38%] "peeling scaling or flaking of skin on breast" (closest: "pain or soreness of breast")
#   [ 38%] "rigid penile shaft" (closest: "penile discharge")
#   [ 38%] "white fluid in front of eye" (closest: "white discharge from eye")
#   [ 38%] "pain when swallowing" (closest: "difficulty swallowing")
#   [ 38%] "urinary incontinence" (closest: "incontinence of stool")
#   [ 38%] "cold clammy skin" (closest: "dry skin")
#   [ 38%] "rough scaly skin" (closest: "dry skin")
#   [ 38%] "skin turn blue" (closest: "skin moles")
#   [ 38%] "skin turn white" (closest: "skin rash")
#   [ 38%] "speaking quietly" (closest: "difficulty speaking")
#   [ 38%] "loose stools" (closest: "discharge in stools")
#   [ 38%] "cutaneous skin" (closest: "dry skin")
#   [ 38%] "stuffy or swollen nose" (closest: "swollen or red tonsils")
#   [ 38%] "irregular menstrual cycles" (closest: "irregular heartbeat")
#   [ 37%] "nosebleeds" (closest: "nosebleed")
#   [ 37%] "sideways curvature of the spine" (closest: "symptoms of the kidneys")
#   [ 37%] "passing of gas through the vagina" (closest: "pain of the anus")
#   [ 37%] "severe or ongoing constipation" (closest: "constipation")
#   [ 37%] "numbess in leg" (closest: "redness in ear")
#   [ 37%] "headaches" (closest: "headache")
#   [ 37%] "vomitting" (closest: "vomiting")
#   [ 37%] "weakeness" (closest: "weakness")
#   [ 37%] "burning pain in hands or feet" (closest: "burning chest pain")
#   [ 37%] "abdominal cramps after eating" (closest: "abdominal swelling")
#   [ 37%] "narrow finger nails" (closest: "brittle nails")
#   [ 37%] "vaginal fluid called discharge that smells unusual" (closest: "vaginal discharge")
#   [ 37%] "bad breath" (closest: "hurts to breath")
#   [ 37%] "trouble with speech" (closest: "problems with movement")
#   [ 37%] "seizures" (closest: "seizure")
#   [ 37%] "heart beat changes" (closest: "heart palpitations")
#   [ 37%] "irritation on perineum" (closest: "eye irritation")
#   [ 37%] "missed periods" (closest: "long menstrual periods")
#   [ 37%] "coughing up large amounts of mucus" (closest: "coughing up sputum")
#   [ 37%] "nipple turned inwards" (closest: "feet turned in")
#   [ 37%] "numbness in your feet" (closest: "numbness")
#   [ 36%] "thirsty" (closest: "thirst")
#   [ 36%] "acne" (closest: "acne or pimples")
#   [ 36%] "rose spots rash" (closest: "rash")
#   [ 36%] "stiff neck" (closest: "neck mass")
#   [ 36%] "bump on eyeball" (closest: "bumps on penis")
#   [ 36%] "low energy" (closest: "low-set ears")
#   [ 36%] "writhing movements" (closest: "abnormal involuntary movements")
#   [ 36%] "poor balance or coordination" (closest: "loss of coordination")
#   [ 36%] "confusion or difficulty thinking" (closest: "difficulty breathing")
#   [ 36%] "pinpoint pupils" (closest: "pupils unequal")
#   [ 36%] "uncontrolled movements" (closest: "abnormal involuntary movements")
#   [ 36%] "bleeding for a long time from an injury" (closest: "bleeding or discharge from nipple")
#   [ 36%] "enlarged pupil one eye" (closest: "enlarged liver")
#   [ 36%] "thick skin around the stump" (closest: "mass or swelling around the anus")
#   [ 36%] "fefver" (closest: "fever")
#   [ 36%] "decreased mental sharpness" (closest: "decreased heart rate")
#   [ 36%] "numbness in your hands" (closest: "numbness")
#   [ 36%] "pounding heart" (closest: "rapid heart rate")
#   [ 36%] "slow-healing sores" (closest: "slow heart rate")
#   [ 36%] "green or dark brown nonbloody nipple discharge" (closest: "bleeding or discharge from nipple")
#   [ 36%] "poor hand-eye coordination" (closest: "loss of coordination")
#   [ 36%] "heart murmur" (closest: "heart palpitations")
#   [ 36%] "pain near injury" (closest: "pain")
#   [ 35%] "dry coarse hair" (closest: "dry skin")
#   [ 35%] "slow flapping movement of the arms" (closest: "pain of the anus")
#   [ 35%] "cup-shaped ears" (closest: "low-set ears")
#   [ 35%] "reduced fetal movement" (closest: "problems with movement")
#   [ 35%] "enlargement of tongue" (closest: "swollen tongue")
#   [ 35%] "loss of feeling in arms and legs" (closest: "plugged feeling in ear")
#   [ 35%] "swelling in either testicle" (closest: "pain in testicles")
#   [ 35%] "leaking of stool through the vagina" (closest: "pain of the anus")
#   [ 35%] "leaking of urine through the vagina" (closest: "pain of the anus")
#   [ 35%] "cold toes" (closest: "feeling cold")
#   [ 35%] "pain when talking" (closest: "pain")
#   [ 35%] "pimple on eyeball" (closest: "mass on eyelid")
#   [ 35%] "skin that's cold" (closest: "skin irritation")
#   [ 35%] "mipple discharge from more than one milk duct" (closest: "white discharge from eye")
#   [ 35%] "stool mixed with blood" (closest: "blood in stool")
#   [ 35%] "bloody stools" (closest: "discharge in stools")
#   [ 35%] "mild cramping on abdomen" (closest: "cramping")
#   [ 34%] "dark lines on nail" (closest: "dark urine")
#   [ 34%] "liver failure" (closest: "enlarged liver")
#   [ 34%] "reduced pain sensation" (closest: "loss of sensation")
#   [ 34%] "long lasting erection" (closest: "long menstrual periods")
#   [ 34%] "darkened skin patches" (closest: "dry skin")
#   [ 34%] "slow wound healing" (closest: "slow growth")
#   [ 34%] "blisters on chest" (closest: "congestion in chest")
#   [ 34%] "foot deformities" (closest: "foot or toe weakness")
#   [ 34%] "body aches" (closest: "lower body pain")
#   [ 34%] "moon face" (closest: "symptoms of the face")
#   [ 34%] "pulsing in the nect" (closest: "pain in eye")
#   [ 33%] "fluid buildup around the lungs" (closest: "mass or swelling around the anus")
#   [ 33%] "general body aches" (closest: "lower body pain")
#   [ 33%] "muscle stiffness in back shoulders arms and legs" (closest: "muscle stiffness or tightness")
#   [ 33%] "difficulty hearing low-pitched sounds" (closest: "difficulty eating")
#   [ 33%] "change in bowel habits" (closest: "discharge in stools")
#   [ 33%] "general feeling of discomfort" (closest: "swelling of scrotum")
#   [ 33%] "neusea" (closest: "nausea")
#   [ 33%] "pink or purple stretch marks on the skin" (closest: "wrinkles on skin")
#   [ 33%] "cold fingers" (closest: "feeling cold")
#   [ 33%] "breast nodules change in size with menstrual cycle" (closest: "change in skin mole size or color")
#   [ 33%] "low hairline at the back of the neck" (closest: "low back weakness")
#   [ 33%] "enlarged head in infants" (closest: "enlarged liver")
#   [ 33%] "fluid collecting around the back of the neck" (closest: "mass or swelling around the anus")
#   [ 32%] "sudden bleeding into joints" (closest: "tongue bleeding")
#   [ 32%] "confusion or loss of touch with reality" (closest: "pain or soreness of breast")
#   [ 32%] "a lump on neck" (closest: "bumps on penis")
#   [ 32%] "growth on kidney" (closest: "kidney mass")
#   [ 32%] "red discolored skin" (closest: "dry skin")
#   [ 32%] "severe pain at site of injury" (closest: "pain of the anus")
#   [ 32%] "bowed or bent bones" (closest: "bowlegged or knock-kneed")
#   [ 32%] "blisters on back" (closest: "mass on ear")
#   [ 32%] "thick ear-lobes" (closest: "itchy ear(s)")
#   [ 32%] "receding lower jaw" (closest: "lump over jaw")
#   [ 32%] "sores on thighs" (closest: "wrinkles on skin")
#   [ 32%] "shaky hands or arms" (closest: "back cramps or spasms")
#   [ 32%] "inflamation of tendons" (closest: "incontinence of stool")
#   [ 32%] "depressed mood" (closest: "mood changes")
#   [ 32%] "foamy spots in the white of eyes" (closest: "symptoms of the kidneys")
#   [ 32%] "pain from wearing shoes" (closest: "pus draining from ear")
#   [ 32%] "rashes" (closest: "rash")
#   [ 32%] "blisters on shoulders" (closest: "mass on ear")
#   [ 32%] "congenital heart disease" (closest: "decreased heart rate")
#   [ 32%] "little fetal activity" (closest: "too little hair")
#   [ 31%] "flu" (closest: "flu-like syndrome")
#   [ 31%] "issues with cognitive development" (closest: "problems with movement")
#   [ 31%] "bruises with small injuries" (closest: "problems with balance")
#   [ 31%] "over sleepy" (closest: "lump over jaw")
#   [ 31%] "low exercise tolerance" (closest: "low self-esteem")
#   [ 31%] "sores on groin area" (closest: "mass on ear")
#   [ 31%] "sweaty or clammy skin" (closest: "dry skin")
#   [ 31%] "reduced temperature sensation" (closest: "loss of sensation")
#   [ 31%] "numbness in the hands or feet" (closest: "redness in or around nose")
#   [ 31%] "burning feeling while urinating" (closest: "feeling hot")
#   [ 30%] "changes with facial bones" (closest: "problems with balance")
#   [ 30%] "blood-streaked sputum" (closest: "pus in sputum")
#   [ 30%] "soreness" (closest: "pain or soreness of breast")
#   [ 30%] "gurgling noise at back of the throat" (closest: "itching of the anus")
#   [ 30%] "weakness on one side of the body" (closest: "symptoms of the kidneys")
#   [ 30%] "amnesia" (closest: "anemia")
#   [ 30%] "puffy face" (closest: "symptoms of the face")
#   [ 30%] "green or brown vomit" (closest: "redness in or around nose")
#   [ 30%] "a slow healing wound" (closest: "slow heart rate")
#   [ 30%] "agitation" (closest: "palpitations")
#   [ 30%] "limits ability to think" (closest: "sensitivity to light")
#   [ 30%] "losing weight without trying" (closest: "weight gain")
#   [ 30%] "white spots on tonsils" (closest: "swollen or red tonsils")
#   [ 30%] "self-injury" (closest: "low self-esteem")
#   [ 30%] "tiny red spots" (closest: "red eye")
#   [ 30%] "hoarseness" (closest: "throat redness")
#   [ 30%] "sedation" (closest: "sweating")
#   [ 30%] "deficiences of certain antibodies" (closest: "absence of menstruation")
#   [ 30%] "skin turn white then blue" (closest: "skin growth")
#   [ 29%] "easily bruised" (closest: "easy bruising")
#   [ 29%] "blisters with yellowish fluid" (closest: "problems with orgasm")
#   [ 29%] "agression" (closest: "depression")
#   [ 29%] "inflamation around joints" (closest: "redness in or around nose")
#   [ 29%] "trouble keeping posture" (closest: "posture problems")
#   [ 29%] "problems in seeing things close or far away" (closest: "problems with shape or size of breast")
#   [ 29%] "foul-smelling greasy stools" (closest: "discharge in stools")
#   [ 29%] "uncapable of being pregnant" (closest: "shortness of breath")
#   [ 29%] "confabulation" (closest: "confusion")
#   [ 29%] "tiredness" (closest: "penis redness")
#   [ 29%] "lacy white patches on tongue" (closest: "swollen tongue")
#   [ 28%] "cool feet" (closest: "feet turned in")
#   [ 28%] "flat feet" (closest: "feet turned in")
#   [ 28%] "warmth around joint" (closest: "joint pain")
#   [ 28%] "white patches on inside of cheeks" (closest: "itchiness of eye")
#   [ 28%] "feeling of incomplete bowel emptying" (closest: "feeling ill")
#   [ 28%] "extreme tiredness" (closest: "eye redness")
#   [ 28%] "constant urge to urinate" (closest: "hurts to breath")
#   [ 28%] "indigestion-like discomfort" (closest: "flu-like syndrome")
#   [ 28%] "warts around genital area" (closest: "warts")
#   [ 28%] "thickened area on breast" (closest: "pain or soreness of breast")
#   [ 28%] "progressively worsening penile pain" (closest: "burning abdominal pain")
#   [ 28%] "pounding heartbeats" (closest: "rapid heartbeat")
#   [ 27%] "flattened nipple" (closest: "bleeding or discharge from nipple")
#   [ 27%] "inflammation" (closest: "lacrimation")
#   [ 27%] "thick or hard patches" (closest: "acne or pimples")
#   [ 27%] "unusual paleness" (closest: "unusual color or odor to urine")
#   [ 27%] "colors seem to be faded" (closest: "hurts to breath")
#   [ 27%] "sores around reproductive orga" (closest: "mass or swelling around the anus")
#   [ 27%] "black tarry or bloody stools" (closest: "discharge in stools")
#   [ 27%] "fatty lump between shoulders" (closest: "lump in throat")
#   [ 27%] "small red spots beneath the skin" (closest: "symptoms of the kidneys")
#   [ 26%] "body shape too big" (closest: "lower body pain")
#   [ 26%] "growth of calluses from affected toe" (closest: "lack of growth")
#   [ 26%] "non-healing sores on feet or toes" (closest: "skin on leg or foot looks infected")
#   [ 26%] "clumsiness" (closest: "numbness")
#   [ 26%] "fainting" (closest: "fatigue")
#   [ 26%] "itchness" (closest: "itchiness of eye")
#   [ 26%] "morning headaches" (closest: "frontal headache")
#   [ 26%] "trouble moving" (closest: "double vision")
#   [ 26%] "trouble walking" (closest: "sleepwalking")
#   [ 26%] "very thirsty" (closest: "thirst")
#   [ 26%] "dull ache in the lower belly or groin" (closest: "redness in or around nose")
#   [ 25%] "toe shorter than the rest" (closest: "postpartum problems of the breast")
#   [ 25%] "urinating often" (closest: "itching of the anus")
#   [ 25%] "behavioral change" (closest: "vision changes")
#   [ 25%] "trouble sleeping" (closest: "tongue bleeding")
#   [ 25%] "aching joints" (closest: "itching of skin")
#   [ 25%] "disorientation" (closest: "eye irritation")
#   [ 25%] "trouble focusin" (closest: "double vision")
#   [ 25%] "small painless bumps beneath the skin" (closest: "wrinkles on skin")
#   [ 25%] "diverticulitis" (closest: "infertility")
#   [ 25%] "tenderness" (closest: "lightheadedness")
#   [ 25%] "sluggishness" (closest: "sleepiness")
#   [ 25%] "patches with rough ridged wrinkled or smooth surface" (closest: "problems with shape or size of breast")
#   [ 25%] "fussiness" (closest: "drowsiness")
#   [ 25%] "belching" (closest: "bloating")
#   [ 25%] "blocked intestines" (closest: "blood in urine")
#   [ 25%] "cognitive or developmental delays" (closest: "acne or pimples")
#   [ 25%] "mumbling" (closest: "bloating")
#   [ 25%] "sepsis" (closest: "hemoptysis")
#   [ 24%] "cloudy or star-shaped cataracts in the eyes" (closest: "mass or swelling around the anus")
#   [ 24%] "opening of previously closed wounds" (closest: "swelling of scrotum")
#   [ 24%] "increased blood count of gamma globulins" (closest: "increased heart rate")
#   [ 24%] "breast tenderness" (closest: "restlessness")
#   [ 24%] "nail scarring" (closest: "penile discharge")
#   [ 24%] "descreased reflexes" (closest: "decreased heart rate")
#   [ 24%] "extreme exhaustion" (closest: "premature ejaculation")
#   [ 24%] "sores" (closest: "lip sore")
#   [ 24%] "faint pink spots" (closest: "pain in testicles")
#   [ 24%] "breast lumps" (closest: "lump or mass of breast")
#   [ 24%] "protein levels higher or lower than expected" (closest: "skin on leg or foot looks infected")
#   [ 24%] "blisters" (closest: "low-set ears")
#   [ 24%] "bowel obstruction" (closest: "absence of menstruation")
#   [ 24%] "burpin" (closest: "pain")
#   [ 24%] "fainting when standing" (closest: "burning chest pain")
#   [ 24%] "hypotension" (closest: "confusion")
#   [ 24%] "salt craving" (closest: "cramping")
#   [ 24%] "worsening asthma" (closest: "breathing fast")
#   [ 23%] "not responding to loud noises" (closest: "redness in or around nose")
#   [ 23%] "overlapping fingers" (closest: "abnormal appearing tongue")
#   [ 23%] "crying without tears" (closest: "ringing in ear")
#   [ 23%] "shivering" (closest: "flushing")
#   [ 23%] "trouble remembering" (closest: "tongue bleeding")
#   [ 23%] "discoloration" (closest: "dehydration")
#   [ 23%] "hyperactivity" (closest: "infertility")
#   [ 23%] "pregnant" (closest: "recent pregnancy")
#   [ 23%] "structural abnormalities of a fetus' internal organs" (closest: "disturbance of smell or taste")
#   [ 22%] "dizzy" (closest: "dizziness")
#   [ 22%] "osteoporosis" (closest: "posture problems")
#   [ 22%] "shakes" (closest: "weakness")
#   [ 22%] "failure to pass stool after birth" (closest: "changes in stool appearance")
#   [ 22%] "breast discomfort" (closest: "lump or mass of breast")
#   [ 22%] "clubfeet" (closest: "cloudy eye")
#   [ 22%] "tremors" (closest: "memory loss")
#   [ 22%] "vertigo" (closest: "dehydration")
#   [ 22%] "watery eyes" (closest: "red eye")
#   [ 22%] "weak pulse" (closest: "weakness")
#   [ 22%] "wide nect" (closest: "side pain")
#   [ 22%] "delayed puberty" (closest: "enlarged liver")
#   [ 22%] "few wet diapers" (closest: "elbow weakness")
#   [ 22%] "loosened teeth" (closest: "low self-esteem")
#   [ 22%] "lumpy bruises" (closest: "arm lump or mass")
#   [ 21%] "choking" (closest: "itching of skin")
#   [ 21%] "hernias" (closest: "rash")
#   [ 21%] "missing knuckle" (closest: "swelling of ankles")
#   [ 21%] "uncoordinated walking" (closest: "foot or toe swelling")
#   [ 21%] "arms that point out slightly at the elbows" (closest: "itching of the anus")
#   [ 21%] "iris that jiggles" (closest: "pain in testicles")
#   [ 20%] "electrolyte imbalance" (closest: "problems with balance")
#   [ 20%] "birth defects" (closest: "infections")
#   [ 20%] "small physical size" (closest: "abnormal size or shape of ear")
#   [ 20%] "white or gray patches that cannot be wiped away" (closest: "hand or finger stiffness or tightness")
#   [ 20%] "constant hunger" (closest: "constipation")
#   [ 20%] "tissue death" (closest: "hurts to breath")
#   [ 20%] "salty-tasting sweat" (closest: "palpitations")
#   [ 20%] "long-lasting cough with thick mucus" (closest: "problems with orgasm")
#   [ 20%] "repeated pancreatitis" (closest: "heart palpitations")
#   [ 20%] "repeated pneumonia" (closest: "premature ejaculation")
#   [ 20%] "altered mental state" (closest: "absence of menstruation")
#   [ 20%] "trouble processing information" (closest: "bleeding in mouth")
#   [ 20%] "altered mental status" (closest: "absence of menstruation")
#   [ 20%] "disseminated sporotrichosis" (closest: "diminished vision")
#   [ 20%] "lethargy" (closest: "low-set ears")
#   [ 20%] "reduced reflexes" (closest: "sore muscles")
#   [ 20%] "small placenta" (closest: "abdominal pain")
#   [ 20%] "sudden jerks" (closest: "fluid in ear")
#   [ 20%] "tender stump" (closest: "delirium")
#   [ 20%] "visual field gaps" (closest: "vaginal redness")
#   [ 19%] "trouble moving affected toe" (closest: "foot or toe pain")
#   [ 19%] "reduced mental sharpness" (closest: "frequent menstruation")
#   [ 19%] "lethargic" (closest: "penile discharge")
#   [ 18%] "smaller than average ovaries" (closest: "shoulder stiffness or tightness")
#   [ 18%] "weakened tooth enamel" (closest: "unwanted hair")
#   [ 18%] "extra fuild behind a fetus' next" (closest: "vaginal bleeding after menopause")
#   [ 18%] "webbed nect" (closest: "frequent infections")
#   [ 18%] ""notes": "cleavland clinic" (closest: "obsessions and compulsions")
#   [ 18%] "acid reflux" (closest: "rapid breathing")
#   [ 18%] "cervical insufficiency" (closest: "vaginal discharge")
#   [ 18%] "fussy" (closest: "flushing")
#   [ 17%] "shock" (closest: "rash")
#   [ 17%] "internal organs functioning differently" (closest: "premenstrual tension or irritability")
#   [ 16%] "blisters filled wtih bloody fuild" (closest: "low blood sugar")

# %% [markdown]
# ---
#
# ## 2. Duplicate Detection Across Datasets
#
# Finds symptoms that normalize to the same canonical form across different datasets.

# %%
NON_SYMPTOM_COLS = {'diseases', 'disease_category', 'symptoms', 'age', 'gender', 
                   'age_group', 'weight', 'height', 'bmi', 'occupation', 'sex'}

def analyze_csv_duplicates(filepath: Path) -> dict:
    """Analyze symptom columns in a CSV file for duplicates."""
    print(f"\n{'='*60}")
    print(f"Analyzing: {filepath.name}")
    print(f"{'='*60}")
    
    if not filepath.exists():
        print(f"  File not found")
        return {}
    
    # Load just column names
    df = pd.read_csv(filepath, nrows=0)
    cols = df.columns.tolist()
    
    print(f'Total columns: {len(cols)}')
    
    # Find symptom columns
    symptom_cols = [c for c in cols if c.lower() not in NON_SYMPTOM_COLS]
    print(f'Symptom columns: {len(symptom_cols)}')
    
    # Group by normalized form
    normalized_map = {}
    for col in symptom_cols:
        norm = normalize_symptom(col)
        if norm not in normalized_map:
            normalized_map[norm] = []
        normalized_map[norm].append(col)
    
    # Find groups with duplicates
    duplicates = {k: v for k, v in normalized_map.items() if len(v) > 1}
    
    if duplicates:
        print(f'\nDuplicate symptom groups: {len(duplicates)}')
        for norm, cols_list in list(duplicates.items())[:10]:
            print(f'  "{norm}": {cols_list}')
        if len(duplicates) > 10:
            print(f'  ... and {len(duplicates) - 10} more groups')
    else:
        print('\nNo duplicate symptoms found!')
    
    print(f'\nCould reduce from {len(symptom_cols)} to {len(normalized_map)} unique symptoms')
    return duplicates

# %%
# Analyze all relevant datasets
files = [
    project_root / 'data' / 'raw' / 'symptoms' / 'Disease and symptoms dataset.csv',
    project_root / 'data' / 'processed' / 'symptoms' / 'symptoms_to_disease_cleaned.csv',
    project_root / 'data' / 'processed' / 'symptoms' / 'symptoms_augmented_with_demographics.csv',
]

all_duplicates = {}
for f in files:
    if f.exists():
        dups = analyze_csv_duplicates(f)
        all_duplicates[f.name] = dups

print(f"\n{'='*60}")
print("OVERALL SUMMARY")
print(f"{'='*60}")
for name, dups in all_duplicates.items():
    print(f"  {name}: {len(dups)} duplicate groups")
# Out:
# ============================================================
# Analyzing: Disease and symptoms dataset.csv
# ============================================================
# Total columns: 376
# Symptom columns: 375
#
# No duplicate symptoms found!
#
# Could reduce from 375 to 375 unique symptoms
#
# ============================================================
# Analyzing: symptoms_to_disease_cleaned.csv
# ============================================================
# Total columns: 377
# Symptom columns: 375
#
# No duplicate symptoms found!
#
# Could reduce from 375 to 375 unique symptoms
#
# ============================================================
# Analyzing: symptoms_augmented_with_demographics.csv
# ============================================================
# Total columns: 458
# Symptom columns: 454
#
# No duplicate symptoms found!
#
# Could reduce from 454 to 454 unique symptoms
#
# ============================================================
# OVERALL SUMMARY
# ============================================================
#   Disease and symptoms dataset.csv: 0 duplicate groups
#   symptoms_to_disease_cleaned.csv: 0 duplicate groups
#   symptoms_augmented_with_demographics.csv: 0 duplicate groups

# %% [markdown]
# ---
#
# ## 3. Merge Impact Analysis
#
# Shows exactly what would change if we merge duplicate columns:
# - How many rows have differences between duplicate columns
# - Which diseases would be affected
# - The overall data preservation rate

# %%
def analyze_merge_impact(filepath: Path):
    """Analyze what would change when merging duplicate columns."""
    print(f"\n{'='*70}")
    print(f"MERGE IMPACT ANALYSIS: {filepath.name}")
    print(f"{'='*70}")
    
    if not filepath.exists():
        print(f"  File not found")
        return
    
    # Load data
    print(f"Loading dataset...")
    df = pd.read_csv(filepath)
    print(f"Loaded {len(df):,} rows, {len(df.columns)} columns")
    
    # Find duplicates
    normalized_map = {}
    for col in df.columns:
        if col.lower() in NON_SYMPTOM_COLS:
            continue
        norm = normalize_symptom(col)
        if norm not in normalized_map:
            normalized_map[norm] = []
        normalized_map[norm].append(col)
    
    duplicates = {k: v for k, v in normalized_map.items() if len(v) > 1}
    
    if not duplicates:
        print("No duplicate columns found!")
        return
    
    print(f"\nFound {len(duplicates)} duplicate groups to analyze")
    print("-" * 70)
    
    total_gained = 0
    results = []
    
    for canonical, cols in duplicates.items():
        subset = df[cols].copy()
        
        all_zero = (subset.sum(axis=1) == 0).sum()
        all_one = (subset.min(axis=1) == 1).sum()
        mixed = len(df) - all_zero - all_one
        
        if mixed > 0:
            # Get affected diseases
            if 'diseases' in df.columns:
                mixed_mask = (subset.sum(axis=1) > 0) & (subset.min(axis=1) == 0)
                affected = df.loc[mixed_mask, 'diseases'].value_counts().head(3)
                affected_str = ', '.join([f"{d} ({c})" for d, c in affected.items()])
            else:
                affected_str = "N/A"
            
            results.append({
                'canonical': canonical,
                'columns': len(cols),
                'mixed_rows': mixed,
                'affected': affected_str
            })
            total_gained += mixed
    
    # Display as table
    if results:
        results_df = pd.DataFrame(results)
        results_df = results_df.sort_values('mixed_rows', ascending=False)
        display(results_df)
    
    print(f"\n{'='*70}")
    print(f"SUMMARY")
    print(f"{'='*70}")
    print(f"  Total rows in dataset: {len(df):,}")
    print(f"  Rows with conflicting values: {total_gained:,} ({100*total_gained/len(df):.2f}%)")
    print(f"\n  Merge strategy: MAX (if any column = 1, result = 1)")
    print(f"  Effect: We GAIN {total_gained:,} symptom signals (no information lost)")
    print(f"\n  This is SAFE - merging only adds information, never removes it.")

# %%
# Analyze the augmented dataset (most duplicates)
augmented_path = project_root / 'data' / 'processed' / 'symptoms' / 'symptoms_augmented_with_demographics.csv'
if augmented_path.exists():
    analyze_merge_impact(augmented_path)
# Out:
# ======================================================================
# MERGE IMPACT ANALYSIS: symptoms_augmented_with_demographics.csv
# ======================================================================
# Loading dataset...
# Loaded 223,944 rows, 458 columns
# No duplicate columns found!

# %% [markdown]
# ---
#
# ## 4. Normalizer Configuration
#
# Shows the current normalization rules being applied.

# %%
print("=== TYPO CORRECTIONS ===")
for typo, correct in sorted(TYPO_MAP.items()):
    print(f"  '{typo}' -> '{correct}'")

print(f"\n=== PLURAL TO SINGULAR ===")
for plural, singular in sorted(PLURAL_MAP.items()):
    print(f"  '{plural}' -> '{singular}'")

print(f"\n=== SYNONYM MAPPINGS ===")
for synonym, canonical in sorted(SYNONYM_MAP.items()):
    print(f"  '{synonym}' -> '{canonical}'")
# Out:
# === TYPO CORRECTIONS ===
#   'apetite' -> 'appetite'
#   'burpin' -> 'burping'
#   'dizzy' -> 'dizziness'
#   'fefver' -> 'fever'
#   'itchness' -> 'itchiness'
#   'lack of apetite' -> 'loss of appetite'
#   'loss of apetite' -> 'loss of appetite'
#   'loss of consiousness' -> 'loss of consciousness'
#   'nausea and vomitting' -> 'nausea and vomiting'
#   'neusea' -> 'nausea'
#   'numbess' -> 'numbness'
#   'paleness' -> 'pallor'
#   'regurgitation.1' -> 'regurgitation'
#   'ringing in ears' -> 'ringing in ear'
#   'slowhealing' -> 'slow healing'
#   'stiffeness' -> 'stiffness'
#   'thirsty' -> 'thirst'
#   'tireness' -> 'tiredness'
#   'vomitting' -> 'vomiting'
#   'weakeness' -> 'weakness'
#
# === PLURAL TO SINGULAR ===
#   'bloody stools' -> 'bloody stool'
#   'body aches' -> 'body ache'
#   'chills' -> 'chills'
#   'headaches' -> 'headache'
#   'irregular heartbeats' -> 'irregular heartbeat'
#   'muscle aches' -> 'muscle ache'
#   'nosebleeds' -> 'nosebleed'
#   'numbness in arms' -> 'numbness in arm'
#   'numbness in legs' -> 'numbness in leg'
#   'rashes' -> 'rash'
#   'ringing in ears' -> 'ringing in ear'
#   'seizures' -> 'seizure'
#   'swelling of eyelids' -> 'swelling of eyelid'
#   'swelling of feets' -> 'swelling of feet'
#   'swollen glands' -> 'swollen lymph nodes'
#   'swollen lymph glands' -> 'swollen lymph nodes'
#
# === SYNONYM MAPPINGS ===
#   'abdominal cramps' -> 'abdominal pain'
#   'abdominal distention' -> 'bloating'
#   'belching' -> 'bloating'
#   'belly pain' -> 'abdominal pain'
#   'blood in feces' -> 'blood in stool'
#   'bloody stool' -> 'blood in stool'
#   'blurred vision' -> 'blurred vision'
#   'blurry vision' -> 'blurred vision'
#   'changes in skin color' -> 'skin color changes'
#   'decreased appetite' -> 'loss of appetite'
#   'difficulty in swallowing' -> 'difficulty swallowing'
#   'discomfort in chest' -> 'chest pain'
#   'dizzy' -> 'dizziness'
#   'dry mouth and lips' -> 'dry mouth'
#   'extreme fatigue' -> 'fatigue'
#   'extreme tiredness' -> 'fatigue'
#   'eye inflammation' -> 'eye redness'
#   'facial swelling' -> 'swelling'
#   'failure to gain weight' -> 'poor weight gain'
#   'fainting' -> 'loss of consciousness'
#   'fast heart beat' -> 'fast heart rate'
#   'fast heartbeats' -> 'fast heart rate'
#   'feeling bloated' -> 'bloating'
#   'feeling tired' -> 'fatigue'
#   'feeling weak' -> 'weakness'
#   'gas pain' -> 'gas'
#   'heart failure' -> 'heart palpitations'
#   'heavy menstrual periods' -> 'heavy menstrual flow'
#   'high bmi' -> 'obesity'
#   'hoarseness' -> 'hoarse voice'
#   'involuntary eye movements' -> 'eye moves abnormally'
#   'irregular periods' -> 'irregular menstrual cycles'
#   'itching' -> 'itching of skin'
#   'itchy skin' -> 'itching of skin'
#   'lack of apetite' -> 'loss of appetite'
#   'lack of appetite' -> 'loss of appetite'
#   'lack of coordination' -> 'loss of coordination'
#   'lethargy' -> 'fatigue'
#   'light sensitivity' -> 'sensitivity to light'
#   'losing weight' -> 'weight loss'
#   'loss of apetite' -> 'loss of appetite'
#   'loss of balance' -> 'problems with balance'
#   'loss of smell' -> 'disturbance of smell or taste'
#   'loss of touch' -> 'loss of sensation'
#   'lump on vulva' -> 'mass on vulva'
#   'muscle or joint pain' -> 'muscle pain'
#   'muscle tightness' -> 'muscle stiffness or tightness'
#   'nausea and vomitting' -> 'nausea and vomiting'
#   'pain during sex' -> 'pain during intercourse'
#   'pain in joint' -> 'joint pain'
#   'pain when swallowing' -> 'difficulty swallowing'
#   'pale skin' -> 'pallor'
#   'pink eye' -> 'eye redness'
#   'poor apetite' -> 'loss of appetite'
#   'poor appetite' -> 'loss of appetite'
#   'poor coordination' -> 'loss of coordination'
#   'pounding heart' -> 'heart palpitations'
#   'recent weight loss' -> 'weight loss'
#   'redness of eye' -> 'eye redness'
#   'reduced pain sensation' -> 'loss of sensation'
#   'severe headache' -> 'headache'
#   'skin flushing' -> 'flushing'
#   'slow speech' -> 'slurred speech'
#   'slurring words' -> 'slurred speech'
#   'stomach bloating' -> 'bloating'
#   'stomach cramps' -> 'abdominal pain'
#   'stomach pain' -> 'abdominal pain'
#   'swelling in legs' -> 'leg swelling'
#   'swelling of feet' -> 'foot or toe swelling'
#   'swelling of hands' -> 'hand or finger swelling'
#   'swelling of legs' -> 'leg swelling'
#   'swollen abdomen' -> 'swollen abdomen'
#   'swollen feet' -> 'foot or toe swelling'
#   'swollen fingers' -> 'hand or finger swelling'
#   'swollen legs' -> 'leg swelling'
#   'swollen lymph glands' -> 'swollen lymph nodes'
#   'swollen toes' -> 'foot or toe swelling'
#   'swollen tonsils' -> 'swollen or red tonsils'
#   'throwing up' -> 'vomiting'
#   'tiredness' -> 'fatigue'
#   'trouble speaking' -> 'difficulty speaking'
#   'trouble swallowing' -> 'difficulty swallowing'
#   'trouble with vision' -> 'vision problems'
#   'tummy pain' -> 'abdominal pain'
#   'unexplained weight gain' -> 'weight gain'
#   'unexplained weight loss' -> 'weight loss'
#   'unintentional weight loss' -> 'weight loss'
#   'vision less clear' -> 'vision loss'
#   'vomiting blood' -> 'vomiting blood'
#   'yellow skin' -> 'jaundice'
#   'yellowing of skin' -> 'jaundice'

# %% [markdown]
# ---
#
# ## Next Steps
#
# To clean the datasets, run the utility scripts:
#
# ```bash
# # Clean vocabulary files
# python scripts/cleanup_symptom_vocabulary.py --apply
#
# # Clean dataset columns
# python scripts/cleanup_symptom_datasets.py --apply
# ```

# %%
# Load the cleaned dataset (replace path if needed)
cleaned_data_path = project_root / 'data' / 'processed' / 'symptoms' / 'symptoms_augmented_with_demographics.csv'

if cleaned_data_path.exists():
    df_final = pd.read_csv(cleaned_data_path)
    current_cols = set(c for c in df_final.columns if c not in NON_SYMPTOM_COLS)
    
    # Check for alignment
    unrecognized = current_cols - VOCAB_SET
    
    print(f"--- VOCABULARY ALIGNMENT ---")
    print(f"Total symptom columns: {len(current_cols)}")
    if unrecognized:
        print(f"❌ Found {len(unrecognized)} columns NOT in vocabulary:")
        for col in sorted(unrecognized):
            print(f"  - {col}")
    else:
        print("✅ Success: All columns perfectly match the standardized vocabulary.")
# Out:
# --- VOCABULARY ALIGNMENT ---
# Total symptom columns: 454
# ✅ Success: All columns perfectly match the standardized vocabulary.

# %%
# Calculate "Symptom Density"
symptom_counts = df_final[list(current_cols)].sum(axis=1)
empty_rows = (symptom_counts == 0).sum()

print(f"--- DATA INTEGRITY ---")
print(f"Rows with zero symptoms: {empty_rows} ({100*empty_rows/len(df_final):.2f}%)")
print(f"Average symptoms per row: {symptom_counts.mean():.2f}")
print(f"Max symptoms in one row:  {symptom_counts.max()}")

if empty_rows > 0:
    print(f"⚠️ Warning: Found {empty_rows} rows with no symptoms. Consider removing these before training.")
# Out:
# --- DATA INTEGRITY ---
# Rows with zero symptoms: 0 (0.00%)
# Average symptoms per row: 5.33
# Max symptoms in one row:  12

# %%
# Group by symptoms and check for multiple diseases
# We create a 'profile' by joining 0/1 values as a string
symptom_list = sorted(list(current_cols))
df_final['profile'] = df_final[symptom_list].astype(str).agg(''.join, axis=1)

# Find where different diseases share the same profile
collisions = df_final.groupby('profile')['diseases'].nunique()
colliding_profiles = collisions[collisions > 1]

print(f"--- REDUNDANCY & COLLISION CHECK ---")
if not colliding_profiles.empty:
    print(f"❌ Found {len(colliding_profiles)} symptom profiles shared by multiple diseases.")
    # Show an example of a collision
    sample_profile = colliding_profiles.index[0]
    diseases = df_final[df_final['profile'] == sample_profile]['diseases'].unique()
    print(f"Example Collision: {diseases} share the same symptoms.")
else:
    print("✅ Success: Every disease has a unique symptom fingerprint.")

# Cleanup temporary column
df_final.drop(columns=['profile'], inplace=True)
# Out:
# --- REDUNDANCY & COLLISION CHECK ---
# ❌ Found 11379 symptom profiles shared by multiple diseases.
# Example Collision: ['parkinson disease' 'brain cancer' 'anemia' 'multiple myeloma'] share the same symptoms.

# %%
# Check which diseases ended up with very few active symptoms
disease_symptom_stats = df_final.groupby('diseases')[symptom_list].sum().gt(0).sum(axis=1)
weak_coverage = disease_symptom_stats[disease_symptom_stats < 4]

print(f"--- SYMPTOM COVERAGE PER DISEASE ---")
print(f"Total diseases: {len(disease_symptom_stats)}")
if not weak_coverage.empty:
    print(f"⚠️ {len(weak_coverage)} diseases have < 4 symptoms. They may be hard to classify:")
    for disease, count in weak_coverage.items():
        print(f"  - {disease}: {count} symptoms")
else:
    print("✅ All diseases have at least 4 distinct symptoms mapped.")
# Out:
# --- SYMPTOM COVERAGE PER DISEASE ---
# Total diseases: 667
# ⚠️ 35 diseases have < 4 symptoms. They may be hard to classify:
#   - birth trauma: 3 symptoms
#   - carcinoid syndrome: 2 symptoms
#   - cryptorchidism: 3 symptoms
#   - diabetes: 2 symptoms
#   - edward syndrome: 2 symptoms
#   - esophageal varices: 2 symptoms
#   - fetal alcohol syndrome: 3 symptoms
#   - g6pd enzyme deficiency: 2 symptoms
#   - granuloma inguinale: 2 symptoms
#   - high blood pressure: 2 symptoms
#   - hpv: 3 symptoms
#   - huntington disease: 2 symptoms
#   - hypergammaglobulinemia: 2 symptoms
#   - hyperlipidemia: 3 symptoms
#   - insulin overdose: 2 symptoms
#   - intussusception: 3 symptoms
#   - lichen planus: 3 symptoms
#   - lymphogranuloma venereum: 3 symptoms
#   - obesity: 3 symptoms
#   - omphalitis: 3 symptoms
#   - oral leukoplakia: 3 symptoms
#   - otosclerosis: 3 symptoms
#   - pelvic fistula: 3 symptoms
#   - pemphigus: 3 symptoms
#   - raynaud disease: 3 symptoms
#   - reactive arthritis: 2 symptoms
#   - spherocytosis: 3 symptoms
#   - testicular cancer: 3 symptoms
#   - tuberous sclerosis: 3 symptoms
#   - turner syndrome: 2 symptoms
#   - uterine cancer: 3 symptoms
#   - vacterl syndrome: 2 symptoms
#   - vitamin a deficiency: 2 symptoms
#   - vulvar cancer: 3 symptoms
#   - zenker diverticulum: 3 symptoms
